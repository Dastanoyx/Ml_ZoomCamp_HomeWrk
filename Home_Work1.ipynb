# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
np.__version__
# Out:
# '1.20.3'

# %%
data=pd.read_csv('C:/Users/Yasin/ML Zoomcapm/data/data.csv')

# %%
data
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
data['Model'].value_counts()
# Out:
# Silverado 1500        156
# Tundra                140
# F-150                 126
# Sierra 1500            90
# Beetle Convertible     89
#                      ...
# MKZ Hybrid              1
# M4 GTS                  1
# LFA                     1
# Horizon                 1
# Zephyr                  1
# Name: Model, Length: 915, dtype: int64

# %%
df = data.Model.value_counts().loc[]
df.fo
# Out:
# Silverado 1500        156
# Tundra                140
# F-150                 126
# Sierra 1500            90
# Beetle Convertible     89
#                      ...
# MKZ Hybrid              1
# M4 GTS                  1
# LFA                     1
# Horizon                 1
# Zephyr                  1
# Name: Model, Length: 915, dtype: int64

# %%
df1 = data['Model'].value_counts(ascending=True)
df1.head(60)
# Out:
# 1 Series M                          1
# G3                                  1
# Focus RS                            1
# Estate Wagon                        1
# Enzo                                1
# Diablo                              1
# Dawn                                1
# Corniche                            1
# GS F                                1
# Continental GT3-R                   1
# Cayman S                            1
# California T                        1
# Blackwood                           1
# Azure T                             1
# Alpina                              1
# Accord Plug-In Hybrid               1
# 650S Spider                         1
# Continental GT Speed Convertible    1
# 650S Coupe                          1
# Horizon                             1
# M4 GTS                              1
# Yukon Denali                        1
# XC                                  1
# V90                                 1
# Syclone                             1
# ...

# %%
df1.describe()
# Out:
# count    915.000000
# mean      13.020765
# std       14.578416
# min        1.000000
# 25%        4.000000
# 50%        8.000000
# 75%       17.500000
# max      156.000000
# Name: Model, dtype: float64

# %%
data['Make'].value_counts()['Audi']
# Out:
# 328

# %%
data['Make'].describe()
data.Make.describe()
# Out:
# count         11914
# unique           48
# top       Chevrolet
# freq           1123
# Name: Make, dtype: object

# %%
pd.value_counts(data['Model']=='Audi').nunique()
# Out:
# 1

# %%
Audi = data[data['Make']=='Audi']
Audi
# Out:
#        Make Model  Year             Engine Fuel Type  Engine HP  \
# 17     Audi   100  1992             regular unleaded      172.0
# 18     Audi   100  1992             regular unleaded      172.0
# 19     Audi   100  1992             regular unleaded      172.0
# 20     Audi   100  1992             regular unleaded      172.0
# 21     Audi   100  1992             regular unleaded      172.0
# ...     ...   ...   ...                          ...        ...
# 10901  Audi   TTS  2016  premium unleaded (required)      292.0
# 10902  Audi   TTS  2017  premium unleaded (required)      292.0
# 11178  Audi    V8  1992             regular unleaded      276.0
# 11179  Audi    V8  1993             regular unleaded      276.0
# 11180  Audi    V8  1994             regular unleaded      276.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 17                  6.0            MANUAL  front wheel drive              4.0
# ...

# %%
Audi.nunique()
# Out:
# Make                   1
# Model                 34
# Year                  20
# Engine Fuel Type       5
# Engine HP             40
# Engine Cylinders       6
# Transmission Type      3
# Driven_Wheels          2
# Number of Doors        2
# Market Category       15
# Vehicle Size           3
# Vehicle Style          6
# highway MPG           23
# city mpg              18
# Popularity             1
# MSRP                 234
# dtype: int64

# %%
data.isna().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
data["Engine Cylinders"].median()
# Out:
# 6.0

# %%
data["Engine Cylinders"].mode()
# Out:
# 0    4.0
# dtype: float64

# %%
data['Engine Cylinders'].fillna(data["Engine Cylinders"].mode(), inplace = True )
data
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
data['Engine Cylinders'].median()
# Out:
# 6.0

# %%
data.isna().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
Lotus = data[data['Make']=='Lotus']

# %%
Lotus
# Out:
#        Make      Model  Year                Engine Fuel Type  Engine HP  \
# 3912  Lotus      Elise  2009     premium unleaded (required)      189.0
# 3913  Lotus      Elise  2009     premium unleaded (required)      218.0
# 3914  Lotus      Elise  2009     premium unleaded (required)      189.0
# 3915  Lotus      Elise  2010     premium unleaded (required)      189.0
# 3916  Lotus      Elise  2010     premium unleaded (required)      218.0
# 3917  Lotus      Elise  2011     premium unleaded (required)      189.0
# 3918  Lotus      Elise  2011     premium unleaded (required)      217.0
# 3919  Lotus      Elise  2011     premium unleaded (required)      217.0
# 4216  Lotus     Esprit  2002     premium unleaded (required)      350.0
# 4217  Lotus     Esprit  2003     premium unleaded (required)      350.0
# 4218  Lotus     Esprit  2004     premium unleaded (required)      350.0
# 4257  Lotus  Evora 400  2017     premium unleaded (required)      400.0
# ...

# %%
Lotus = Lotus[['Engine HP','Engine Cylinders']]

# %%
Lotus
# Out:
#       Engine HP  Engine Cylinders
# 3912      189.0               4.0
# 3913      218.0               4.0
# 3914      189.0               4.0
# 3915      189.0               4.0
# 3916      218.0               4.0
# 3917      189.0               4.0
# 3918      217.0               4.0
# 3919      217.0               4.0
# 4216      350.0               8.0
# 4217      350.0               8.0
# 4218      350.0               8.0
# 4257      400.0               6.0
# 4258      400.0               6.0
# 4259      276.0               6.0
# 4260      276.0               6.0
# 4261      276.0               6.0
# 4262      345.0               6.0
# 4263      345.0               6.0
# 4264      276.0               6.0
# 4265      345.0               6.0
# 4266      276.0               6.0
# 4267      345.0               6.0
# 4268      276.0               6.0
# 4292      257.0               4.0
# 4293      240.0               4.0
# 4294      240.0               4.0
# ...

# %%
Lotus = Lotus.drop_duplicates()
Lotus
# Out:
#       Engine HP  Engine Cylinders
# 3912      189.0               4.0
# 3913      218.0               4.0
# 3918      217.0               4.0
# 4216      350.0               8.0
# 4257      400.0               6.0
# 4259      276.0               6.0
# 4262      345.0               6.0
# 4292      257.0               4.0
# 4293      240.0               4.0

# %%
x = Lotus.values

# %%
x
# Out:
# array([[189.,   4.],
#        [218.,   4.],
#        [217.,   4.],
#        [350.,   8.],
#        [400.,   6.],
#        [276.,   6.],
#        [345.,   6.],
#        [257.,   4.],
#        [240.,   4.]])

# %%
XTX = x.transpose()
XTX
# Out:
# array([[189., 218., 217., 350., 400., 276., 345., 257., 240.],
#        [  4.,   4.,   4.,   8.,   6.,   6.,   6.,   4.,   4.]])

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_35788/1950352736.py in <module>
# ----> 1 x*t
#
# ValueError: operands could not be broadcast together with shapes (9,2) (2,9)

# %%
y = np.array([1100, 800, 750, 850, 1300, 1000, 1000, 1300, 800])
y
# Out:
# array([1100,  800,  750,  850, 1300, 1000, 1000, 1300,  800])

# %%
(x*XTX)*y
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_35788/2728415577.py in <module>
# ----> 1 (x*XTX)*y
#
# ValueError: operands could not be broadcast together with shapes (9,2) (2,9)
